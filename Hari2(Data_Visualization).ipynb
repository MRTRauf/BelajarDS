# %% [markdown]
# # Hari Kedua

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Pandas untuk mengolah big data (Numpy tidak cukup)

# %%
nama = ['Alpha', 'Beta', 'Charlie', 'Delta', 'Echo', 'Fargo', 'Gundala']
kelas = ['A', 'B', 'B', 'C', 'A', 'B', 'A']
nilai = [10, 80, 90, 78, 30, 60, 80]

# %%
df = pd.DataFrame(data = {'Nama': nama,
                          'Kelas' : kelas,
                          'Nilai' : nilai})

# %%
df
#header = Nama,Kelas,Nilai
#index = 0-6
#dataframe untuk nyimpan data bkn olah (lama waktu process)
# Out:
#       Nama Kelas  Nilai
# 0    Alpha     A     10
# 1     Beta     B     80
# 2  Charlie     B     90
# 3    Delta     C     78
# 4     Echo     A     30
# 5    Fargo     B     60
# 6  Gundala     A     80

# %%
df = df.sort_values(by='Nilai')
df
#databaru ditambah ke baris
# Out:
#       Nama Kelas  Nilai
# 0    Alpha     A     10
# 4     Echo     A     30
# 5    Fargo     B     60
# 3    Delta     C     78
# 1     Beta     B     80
# 6  Gundala     A     80
# 2  Charlie     B     90

# %% [markdown]
# Data per baris

# %%
df.loc[5]
#ambil data tertentu
# Out:
# Nama     Fargo
# Kelas        B
# Nilai       60
# Name: 5, dtype: object

# %%
df.iloc[5]
#berdasarkan urutan ke bawah
# Out:
# Nama     Gundala
# Kelas          A
# Nilai         80
# Name: 6, dtype: object

# %%
df['Nama']
#jadi bentuk data series(1 kolom aja)
# Out:
# 0      Alpha
# 4       Echo
# 5      Fargo
# 3      Delta
# 1       Beta
# 6    Gundala
# 2    Charlie
# Name: Nama, dtype: object

# %%
df[['Nama']]
#jadi bentuk dataframe
# Out:
#       Nama
# 0    Alpha
# 4     Echo
# 5    Fargo
# 3    Delta
# 1     Beta
# 6  Gundala
# 2  Charlie

# %%
df[['Nama','Kelas']]
# Out:
#       Nama Kelas
# 0    Alpha     A
# 4     Echo     A
# 5    Fargo     B
# 3    Delta     C
# 1     Beta     B
# 6  Gundala     A
# 2  Charlie     B

# %%
df
# Out:
#       Nama Kelas  Nilai
# 0    Alpha     A     10
# 4     Echo     A     30
# 5    Fargo     B     60
# 3    Delta     C     78
# 1     Beta     B     80
# 6  Gundala     A     80
# 2  Charlie     B     90

# %%
df['Kelas'] == 'A'
#ambil data boolean
# Out:
# 0     True
# 4     True
# 5    False
# 3    False
# 1    False
# 6     True
# 2    False
# Name: Kelas, dtype: bool

# %%
df[df['Kelas'] == 'A']
#ambil kelas tertentu
# Out:
#       Nama Kelas  Nilai
# 0    Alpha     A     10
# 4     Echo     A     30
# 6  Gundala     A     80

# %%
df[df['Kelas'] == 'A'][df['Nilai']>= 30]
#ambil kelas tertentu dan nilai >= 30
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#       Nama Kelas  Nilai
# 4     Echo     A     30
# 6  Gundala     A     80

# %%
df[df['Kelas'] == 'A'][df['Nilai']>= 30].iloc[0]
#ambil kelas tertentu dan nilai >= 30 dan urutan pertama
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# Nama     Echo
# Kelas       A
# Nilai      30
# Name: 4, dtype: object

# %%
df[df['Kelas'] == 'A'][df['Nilai']>= 30].iloc[1]
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# Nama     Gundala
# Kelas          A
# Nilai         80
# Name: 6, dtype: object

# %%
print(df['Nilai'].max())
#nilai max seluruh

print(df['Nilai'].min())
#nilai min seluruh

print(df['Nilai'].mean())
#nilai rata seluruh

print(df['Nilai'].std())
#nilai standar deviasi
# Out:
# 90
# 10
# 61.142857142857146
# 30.04124149358995

# %%
df['Nilai'].describe()
#penjelasan data
# Out:
# count     7.000000
# mean     61.142857
# std      30.041241
# min      10.000000
# 25%      45.000000
# 50%      78.000000
# 75%      80.000000
# max      90.000000
# Name: Nilai, dtype: float64

# %%
df['Kelas'].unique()
#untuk melihat nilai apa aja yang ada pada kolom tertentu
# Out:
# array(['A', 'B', 'C'], dtype=object)

# %%
iris = pd.read_csv('https://raw.githubusercontent.com/theo123490/basic_python_to_DNN_Tutorials/master/iris.csv')
iris
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
iris['variety'].unique()
#liat nilai yg ada dalam kolom 'variety'
# Out:
# array(['Setosa', 'Versicolor', 'Virginica'], dtype=object)

# %%
iris.head(8)
#panggil beberapa data pertama tergantung nilai dalam tanda kurung
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa
# 5           5.4          3.9           1.7          0.4  Setosa
# 6           4.6          3.4           1.4          0.3  Setosa
# 7           5.0          3.4           1.5          0.2  Setosa

# %%
iris.tail(8)
#panggil beberapa data terakhir tergantung nilai dalam tanda kurung
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 142           5.8          2.7           5.1          1.9  Virginica
# 143           6.8          3.2           5.9          2.3  Virginica
# 144           6.7          3.3           5.7          2.5  Virginica
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica

# %%
iris['sepal.length']
#menunjukkan nilai dlm bentuk series
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal.length, Length: 150, dtype: float64

# %%
iris['sepal.length'].values
#menunjukkan nilai dlm bentuk series
# Out:
# array([5.1, 4.9, 4.7, 4.6, 5. , 5.4, 4.6, 5. , 4.4, 4.9, 5.4, 4.8, 4.8,
#        4.3, 5.8, 5.7, 5.4, 5.1, 5.7, 5.1, 5.4, 5.1, 4.6, 5.1, 4.8, 5. ,
#        5. , 5.2, 5.2, 4.7, 4.8, 5.4, 5.2, 5.5, 4.9, 5. , 5.5, 4.9, 4.4,
#        5.1, 5. , 4.5, 4.4, 5. , 5.1, 4.8, 5.1, 4.6, 5.3, 5. , 7. , 6.4,
#        6.9, 5.5, 6.5, 5.7, 6.3, 4.9, 6.6, 5.2, 5. , 5.9, 6. , 6.1, 5.6,
#        6.7, 5.6, 5.8, 6.2, 5.6, 5.9, 6.1, 6.3, 6.1, 6.4, 6.6, 6.8, 6.7,
#        6. , 5.7, 5.5, 5.5, 5.8, 6. , 5.4, 6. , 6.7, 6.3, 5.6, 5.5, 5.5,
#        6.1, 5.8, 5. , 5.6, 5.7, 5.7, 6.2, 5.1, 5.7, 6.3, 5.8, 7.1, 6.3,
#        6.5, 7.6, 4.9, 7.3, 6.7, 7.2, 6.5, 6.4, 6.8, 5.7, 5.8, 6.4, 6.5,
#        7.7, 7.7, 6. , 6.9, 5.6, 7.7, 6.3, 6.7, 7.2, 6.2, 6.1, 6.4, 7.2,
#        7.4, 7.9, 6.4, 6.3, 6.1, 7.7, 6.3, 6.4, 6. , 6.9, 6.7, 6.9, 5.8,
#        6.8, 6.7, 6.7, 6.3, 6.5, 6.2, 5.9])

# %%
iris[['sepal.length', 'petal.length']].values.T
# Out:
# array([[5.1, 4.9, 4.7, 4.6, 5. , 5.4, 4.6, 5. , 4.4, 4.9, 5.4, 4.8, 4.8,
#         4.3, 5.8, 5.7, 5.4, 5.1, 5.7, 5.1, 5.4, 5.1, 4.6, 5.1, 4.8, 5. ,
#         5. , 5.2, 5.2, 4.7, 4.8, 5.4, 5.2, 5.5, 4.9, 5. , 5.5, 4.9, 4.4,
#         5.1, 5. , 4.5, 4.4, 5. , 5.1, 4.8, 5.1, 4.6, 5.3, 5. , 7. , 6.4,
#         6.9, 5.5, 6.5, 5.7, 6.3, 4.9, 6.6, 5.2, 5. , 5.9, 6. , 6.1, 5.6,
#         6.7, 5.6, 5.8, 6.2, 5.6, 5.9, 6.1, 6.3, 6.1, 6.4, 6.6, 6.8, 6.7,
#         6. , 5.7, 5.5, 5.5, 5.8, 6. , 5.4, 6. , 6.7, 6.3, 5.6, 5.5, 5.5,
#         6.1, 5.8, 5. , 5.6, 5.7, 5.7, 6.2, 5.1, 5.7, 6.3, 5.8, 7.1, 6.3,
#         6.5, 7.6, 4.9, 7.3, 6.7, 7.2, 6.5, 6.4, 6.8, 5.7, 5.8, 6.4, 6.5,
#         7.7, 7.7, 6. , 6.9, 5.6, 7.7, 6.3, 6.7, 7.2, 6.2, 6.1, 6.4, 7.2,
#         7.4, 7.9, 6.4, 6.3, 6.1, 7.7, 6.3, 6.4, 6. , 6.9, 6.7, 6.9, 5.8,
#         6.8, 6.7, 6.7, 6.3, 6.5, 6.2, 5.9],
#        [1.4, 1.4, 1.3, 1.5, 1.4, 1.7, 1.4, 1.5, 1.4, 1.5, 1.5, 1.6, 1.4,
# ...

# %%
data_iris = iris.drop(columns =['variety'])
#menghilangkan kolom variety
data_iris
# Out:
#      sepal.length  sepal.width  petal.length  petal.width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
new_df = iris.copy()

# %%
new_df['total_petal'] = new_df['petal.length']+new_df['petal.width']
#menambahkan kolom baru(dipojok kanan)
new_df
# Out:
#      sepal.length  sepal.width  ...    variety  total_petal
# 0             5.1          3.5  ...     Setosa          1.6
# 1             4.9          3.0  ...     Setosa          1.6
# 2             4.7          3.2  ...     Setosa          1.5
# 3             4.6          3.1  ...     Setosa          1.7
# 4             5.0          3.6  ...     Setosa          1.6
# ..            ...          ...  ...        ...          ...
# 145           6.7          3.0  ...  Virginica          7.5
# 146           6.3          2.5  ...  Virginica          6.9
# 147           6.5          3.0  ...  Virginica          7.2
# 148           6.2          3.4  ...  Virginica          7.7
# 149           5.9          3.0  ...  Virginica          6.9
#
# [150 rows x 6 columns]

# %%
def function(sepal_l, sepal_w, petal_l, petal_w):
  hasil = sepal_l*sepal_w-petal_l+petal_w
  return hasil

function(5, 2, 1,4)
# Out:
# 13

# %%
new_df['function'] = function(new_df['sepal.length'], new_df['sepal.width'], new_df['petal.length'], new_df['petal.width'])
#buat kolom baru
new_df
# Out:
#      sepal.length  sepal.width  petal.length  ...    variety total_petal  function
# 0             5.1          3.5           1.4  ...     Setosa         1.6     16.65
# 1             4.9          3.0           1.4  ...     Setosa         1.6     13.50
# 2             4.7          3.2           1.3  ...     Setosa         1.5     13.94
# 3             4.6          3.1           1.5  ...     Setosa         1.7     12.96
# 4             5.0          3.6           1.4  ...     Setosa         1.6     16.80
# ..            ...          ...           ...  ...        ...         ...       ...
# 145           6.7          3.0           5.2  ...  Virginica         7.5     17.20
# 146           6.3          2.5           5.0  ...  Virginica         6.9     12.65
# 147           6.5          3.0           5.2  ...  Virginica         7.2     16.30
# 148           6.2          3.4           5.4  ...  Virginica         7.7     17.98
# ...

# %%
new_df['lambda'] = new_df.apply(lambda row : row['sepal.length']+row['sepal.width'], axis = 1)
#hitung perbaris
new_df
# Out:
#      sepal.length  sepal.width  petal.length  ...  total_petal function  lambda
# 0             5.1          3.5           1.4  ...          1.6    16.65     8.6
# 1             4.9          3.0           1.4  ...          1.6    13.50     7.9
# 2             4.7          3.2           1.3  ...          1.5    13.94     7.9
# 3             4.6          3.1           1.5  ...          1.7    12.96     7.7
# 4             5.0          3.6           1.4  ...          1.6    16.80     8.6
# ..            ...          ...           ...  ...          ...      ...     ...
# 145           6.7          3.0           5.2  ...          7.5    17.20     9.7
# 146           6.3          2.5           5.0  ...          6.9    12.65     8.8
# 147           6.5          3.0           5.2  ...          7.2    16.30     9.5
# 148           6.2          3.4           5.4  ...          7.7    17.98     9.6
# 149           5.9          3.0           5.1  ...          6.9    14.40     8.9
#
# ...

# %%
titanic = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv')
#1 = selamat, 0 = mati
#string jadi angka, data double dihilangkan, NaN dihilangkan
titanic
# Out:
#      survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 0           0       3    male  22.0  ...   NaN  Southampton     no  False
# 1           1       1  female  38.0  ...     C    Cherbourg    yes  False
# 2           1       3  female  26.0  ...   NaN  Southampton    yes   True
# 3           1       1  female  35.0  ...     C  Southampton    yes  False
# 4           0       3    male  35.0  ...   NaN  Southampton     no   True
# ..        ...     ...     ...   ...  ...   ...          ...    ...    ...
# 886         0       2    male  27.0  ...   NaN  Southampton     no   True
# 887         1       1  female  19.0  ...     B  Southampton    yes   True
# 888         0       3  female   NaN  ...   NaN  Southampton     no  False
# 889         1       1    male  26.0  ...     C    Cherbourg    yes   True
# 890         0       3    male  32.0  ...   NaN   Queenstown     no   True
#
# [891 rows x 15 columns]

# %%
titanic_copy = titanic.copy()
#untuk membersihkan perlu dicopy agar tidak salah

# %% [markdown]
# drop untuk menghilangkan kolom

# %%
titanic_copy = titanic_copy.drop(columns = ['alive','class','embark_town' ,'who','adult_male'])
titanic_copy
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck  alone
# 0           0       3    male  22.0      1      0   7.2500        S  NaN  False
# 1           1       1  female  38.0      1      0  71.2833        C    C  False
# 2           1       3  female  26.0      0      0   7.9250        S  NaN   True
# 3           1       1  female  35.0      1      0  53.1000        S    C  False
# 4           0       3    male  35.0      0      0   8.0500        S  NaN   True
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...    ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN   True
# 887         1       1  female  19.0      0      0  30.0000        S    B   True
# 888         0       3  female   NaN      1      2  23.4500        S  NaN  False
# 889         1       1    male  26.0      0      0  30.0000        C    C   True
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN   True
#
# ...

# %%
titanic_copy.isnull()   #melihat yang NaN ditunjukan dengan True
# Out:
#      survived  pclass    sex    age  ...   fare  embarked   deck  alone
# 0       False   False  False  False  ...  False     False   True  False
# 1       False   False  False  False  ...  False     False  False  False
# 2       False   False  False  False  ...  False     False   True  False
# 3       False   False  False  False  ...  False     False  False  False
# 4       False   False  False  False  ...  False     False   True  False
# ..        ...     ...    ...    ...  ...    ...       ...    ...    ...
# 886     False   False  False  False  ...  False     False   True  False
# 887     False   False  False  False  ...  False     False  False  False
# 888     False   False  False   True  ...  False     False   True  False
# 889     False   False  False  False  ...  False     False  False  False
# 890     False   False  False  False  ...  False     False   True  False
#
# [891 rows x 10 columns]

# %%
titanic_copy.isnull().sum()  #data yang Nan
# Out:
# survived      0
# pclass        0
# sex           0
# age         177
# sibsp         0
# parch         0
# fare          0
# embarked      2
# deck        688
# alone         0
# dtype: int64

# %%
titanic_copy = titanic_copy.drop(columns ='deck')

# %%
titanic_copy
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  alone
# 0           0       3    male  22.0      1      0   7.2500        S  False
# 1           1       1  female  38.0      1      0  71.2833        C  False
# 2           1       3  female  26.0      0      0   7.9250        S   True
# 3           1       1  female  35.0      1      0  53.1000        S  False
# 4           0       3    male  35.0      0      0   8.0500        S   True
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 886         0       2    male  27.0      0      0  13.0000        S   True
# 887         1       1  female  19.0      0      0  30.0000        S   True
# 888         0       3  female   NaN      1      2  23.4500        S  False
# 889         1       1    male  26.0      0      0  30.0000        C   True
# 890         0       3    male  32.0      0      0   7.7500        Q   True
#
# [891 rows x 9 columns]

# %%
titanic_copy.isnull().sum() #cek
# Out:
# survived      0
# pclass        0
# sex           0
# age         177
# sibsp         0
# parch         0
# fare          0
# embarked      2
# alone         0
# dtype: int64

# %%
#menghitung jumlah data tiap kolom, diasumsikan orang berasal dari data paling banyak

titanic_copy['embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: embarked, dtype: int64

# %%
#menunjukkan jumlah data paling banyak

titanic_copy['embarked'].value_counts().idxmax()
# Out:
# 'S'

# %%
titanic_copy['embarked'] = titanic_copy['embarked'].fillna(titanic_copy['embarked'].value_counts().idxmax())
#mengisi nilai yang NaN dengan data yang dianggap paling banyak

# %%
titanic_copy.isnull().sum() #cek
# Out:
# survived      0
# pclass        0
# sex           0
# age         177
# sibsp         0
# parch         0
# fare          0
# embarked      0
# alone         0
# dtype: int64

# %%
titanic_copy = titanic_copy.dropna()

# %%
titanic_copy.isnull().sum() #cek
# Out:
# survived    0
# pclass      0
# sex         0
# age         0
# sibsp       0
# parch       0
# fare        0
# embarked    0
# alone       0
# dtype: int64

# %%
titanic_copy.duplicated().sum() #menunjukkan data duplikasi
# Out:
# 38

# %%
titanic_copy = titanic_copy.drop_duplicates()

# %%
titanic_copy
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  alone
# 0           0       3    male  22.0      1      0   7.2500        S  False
# 1           1       1  female  38.0      1      0  71.2833        C  False
# 2           1       3  female  26.0      0      0   7.9250        S   True
# 3           1       1  female  35.0      1      0  53.1000        S  False
# 4           0       3    male  35.0      0      0   8.0500        S   True
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 883         0       2    male  28.0      0      0  10.5000        S   True
# 885         0       3  female  39.0      0      5  29.1250        Q  False
# 887         1       1  female  19.0      0      0  30.0000        S   True
# 889         1       1    male  26.0      0      0  30.0000        C   True
# 890         0       3    male  32.0      0      0   7.7500        Q   True
#
# [676 rows x 9 columns]

# %%
#One Hot Encoding #menyiapkan untuk ML
pd.get_dummies(titanic_copy['embarked'])
# Out:
#      C  Q  S
# 0    0  0  1
# 1    1  0  0
# 2    0  0  1
# 3    0  0  1
# 4    0  0  1
# ..  .. .. ..
# 883  0  0  1
# 885  0  1  0
# 887  0  0  1
# 889  1  0  0
# 890  0  1  0
#
# [676 rows x 3 columns]

# %%
titanic_copy = titanic_copy.join(pd.get_dummies(titanic_copy['embarked'])) #menyatukan dataframe encoding ke dataframe awal

# %%
titanic_copy = titanic_copy.drop(columns='embarked')
titanic_copy
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare  alone  C  Q  S
# 0           0       3    male  22.0      1      0   7.2500  False  0  0  1
# 1           1       1  female  38.0      1      0  71.2833  False  1  0  0
# 2           1       3  female  26.0      0      0   7.9250   True  0  0  1
# 3           1       1  female  35.0      1      0  53.1000  False  0  0  1
# 4           0       3    male  35.0      0      0   8.0500   True  0  0  1
# ..        ...     ...     ...   ...    ...    ...      ...    ... .. .. ..
# 883         0       2    male  28.0      0      0  10.5000   True  0  0  1
# 885         0       3  female  39.0      0      5  29.1250  False  0  1  0
# 887         1       1  female  19.0      0      0  30.0000   True  0  0  1
# 889         1       1    male  26.0      0      0  30.0000   True  1  0  0
# 890         0       3    male  32.0      0      0   7.7500   True  0  1  0
#
# [676 rows x 11 columns]

# %%
titanic_copy = titanic_copy.join(pd.get_dummies(titanic_copy['sex']))   #join menambahkan dataframe
titanic_copy = titanic_copy.drop(columns='sex')
titanic_copy
# Out:
#      survived  pclass   age  sibsp  parch  ...  C  Q  S  female  male
# 0           0       3  22.0      1      0  ...  0  0  1       0     1
# 1           1       1  38.0      1      0  ...  1  0  0       1     0
# 2           1       3  26.0      0      0  ...  0  0  1       1     0
# 3           1       1  35.0      1      0  ...  0  0  1       1     0
# 4           0       3  35.0      0      0  ...  0  0  1       0     1
# ..        ...     ...   ...    ...    ...  ... .. .. ..     ...   ...
# 883         0       2  28.0      0      0  ...  0  0  1       0     1
# 885         0       3  39.0      0      5  ...  0  1  0       1     0
# 887         1       1  19.0      0      0  ...  0  0  1       1     0
# 889         1       1  26.0      0      0  ...  1  0  0       0     1
# 890         0       3  32.0      0      0  ...  0  1  0       0     1
#
# [676 rows x 12 columns]

# %%
titanic_copy['alone']= titanic_copy['alone'].astype(int) #mengubah data int

# %%
titanic_copy
# Out:
#      survived  pclass   age  sibsp  parch  ...  C  Q  S  female  male
# 0           0       3  22.0      1      0  ...  0  0  1       0     1
# 1           1       1  38.0      1      0  ...  1  0  0       1     0
# 2           1       3  26.0      0      0  ...  0  0  1       1     0
# 3           1       1  35.0      1      0  ...  0  0  1       1     0
# 4           0       3  35.0      0      0  ...  0  0  1       0     1
# ..        ...     ...   ...    ...    ...  ... .. .. ..     ...   ...
# 883         0       2  28.0      0      0  ...  0  0  1       0     1
# 885         0       3  39.0      0      5  ...  0  1  0       1     0
# 887         1       1  19.0      0      0  ...  0  0  1       1     0
# 889         1       1  26.0      0      0  ...  1  0  0       0     1
# 890         0       3  32.0      0      0  ...  0  1  0       0     1
#
# [676 rows x 12 columns]

# %%
plt.scatter(iris['sepal.length'],iris['sepal.width'])

# %%
Setosa = iris[iris['variety'] == 'Setosa']
Setosa
# Out:
#     sepal.length  sepal.width  petal.length  petal.width variety
# 0            5.1          3.5           1.4          0.2  Setosa
# 1            4.9          3.0           1.4          0.2  Setosa
# 2            4.7          3.2           1.3          0.2  Setosa
# 3            4.6          3.1           1.5          0.2  Setosa
# 4            5.0          3.6           1.4          0.2  Setosa
# 5            5.4          3.9           1.7          0.4  Setosa
# 6            4.6          3.4           1.4          0.3  Setosa
# 7            5.0          3.4           1.5          0.2  Setosa
# 8            4.4          2.9           1.4          0.2  Setosa
# 9            4.9          3.1           1.5          0.1  Setosa
# 10           5.4          3.7           1.5          0.2  Setosa
# 11           4.8          3.4           1.6          0.2  Setosa
# 12           4.8          3.0           1.4          0.1  Setosa
# ...

# %%
Versicolor = iris[iris['variety']== 'Versicolor']
Virginica = iris[iris['variety']== 'Virginica']
Versicolor
Virginica
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 100           6.3          3.3           6.0          2.5  Virginica
# 101           5.8          2.7           5.1          1.9  Virginica
# 102           7.1          3.0           5.9          2.1  Virginica
# 103           6.3          2.9           5.6          1.8  Virginica
# 104           6.5          3.0           5.8          2.2  Virginica
# 105           7.6          3.0           6.6          2.1  Virginica
# 106           4.9          2.5           4.5          1.7  Virginica
# 107           7.3          2.9           6.3          1.8  Virginica
# 108           6.7          2.5           5.8          1.8  Virginica
# 109           7.2          3.6           6.1          2.5  Virginica
# 110           6.5          3.2           5.1          2.0  Virginica
# 111           6.4          2.7           5.3          1.9  Virginica
# 112           6.8          3.0           5.5          2.1  Virginica
# ...

# %%
plt.scatter(Setosa['sepal.length'], Setosa['sepal.width'], c='r')
plt.scatter(Versicolor['sepal.length'], Versicolor['sepal.width'], c='g')
plt.scatter(Virginica['sepal.length'], Virginica['sepal.width'], c='b')
plt.show()
#SCATTERPLOT DIAGRAM

plt.scatter(Setosa['sepal.length'], Setosa['sepal.width'], c='r')
plt.scatter(Versicolor['sepal.length'], Versicolor['sepal.width'], c='g')
plt.show()

# %%
x = np.arange(0, 20)
y = np.sin(x)
plt.plot(x,y)

# %%
x = np.linspace(0,20, 50)
y = np.sin(x)
plt.plot(x,y)

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.arange(0, 2*np.pi, 0.02)
y = np.sin(x)
y1 = np.sin(2*x)
y2 = np.sin(3*x)
ym1 = np.ma.masked_where(y1 > 0.5, y1)
ym2 = np.ma.masked_where(y2 < -0.5, y2)

plt.plot(x, y, linewidth = 4)    #linewidth utk  ketebalan
plt.plot(x, ym1, '-x', linewidth=2, markevery = 7)   #'-x' untuk memberi tanda, markevery = tandai setiap 7(misal)
plt.plot(x, ym2, 'o', markersize = 10, markevery = 3)


plt.legend(('No mask', 'Masked if > 0.5', 'Masked if < -0.5'),  #untuklegenda
           loc='upper right')                                   #loc bisa koordinat
plt.title('Masked Line Demo')

plt.ylim(-1.7,1.2)
plt.xlim(-1,7)
plt.ylabel('ini adalah ylabel')
plt.xlabel('ini adalah xlabel')

plt.show()

# %% [markdown]
# **SEABORN**

# %%
sns.scatterplot(data = iris,
                x='sepal.length',
                y = 'sepal.width',
                hue = 'variety',
                style = 'variety')

# %%
sns.scatterplot(data = iris,
                x='sepal.length',
                y = 'sepal.width',
                hue = 'petal.length',
                style = 'variety')

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(data = iris,
                x='sepal.length',
                y = 'sepal.width',
                hue = 'petal.length',
                size = 'petal.width',
                style = 'variety')
plt.legend(loc='lower left')

# %%
sns.pairplot(data = iris)

# %%
sns.pairplot(data = iris, hue ='variety')

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.distplot(tips['total_bill'], rug=True)   #Persebaran #Rug = True untuk lokasi data

# %%
sns.violinplot(data = tips, x = 'day', y ='total_bill', hue= 'smoker')

# %%
sns.violinplot(data = tips, x = 'day', y ='total_bill', hue= 'smoker', split = True)

# %%
sns.violinplot(data = tips, x = 'day', y ='tip', hue= 'smoker', split = True)

# %%
sns.violinplot(x="day", y="total_bill", hue="smoker", palette="Set2", data=tips, split=True, inner='stick')

# %%
sns.violinplot(x="day", y="total_bill", hue="smoker", palette="Set2", data=tips, split=True, inner='quartile')   #inner quartile utk per 25%/kuartil

# %%
sns.jointplot(x='total_bill', y ='tip', data = tips)

# %%
sns.jointplot(x='total_bill', y ='tip', data = tips, kind='hex')

# %%
sns.jointplot(x='total_bill', y ='tip', data = tips, kind='kde')

# %%
sns.jointplot(x='total_bill', y ='tip', data = tips, kind='reg')

# %%
sns.regplot(x="total_bill", y="tip", data=tips, color = 'black')   #bayangan artinya confidence level(butuh data lebih banyak)

# %%
sns.regplot(x="total_bill", y="tip", data=tips, color = 'black', ci=30)

# %%
sns.regplot(x="total_bill", y="tip", data=tips, color = 'black', ci=False) #Ci untuk menunjukkan confidence level, False utk menghilangkan

# %%
sns.regplot(x="size", y="tip", data=tips, color = 'black')

# %%
sns.regplot(x="size", y="tip",x_jitter = 0.1, data=tips, color = 'black')

# %%
sns.regplot(x="size", y="tip",x_estimator= np.mean, data=tips, color = 'black')   #confidence interval per "size"

# %%
fmri = sns.load_dataset('fmri')
fmri
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
sns.lineplot(data=fmri, x = 'timepoint', y = 'signal', hue='event', style='region')

# %%
sns.lineplot(x="timepoint", 
                  y="signal", 
                  hue="event",
                  style='region',
                  estimator = None,
                  units = 'subject',
                  data=fmri)

# %%
sns.barplot(data=titanic, x='embark_town',y='survived', hue = 'sex')     #diagram batang untu melihat data relatif

# %%
sns.barplot(data=titanic, x='embark_town',y='survived', hue = 'sex', estimator = np.sum)

# %%
sns.boxplot(data = tips, x='day', y = 'total_bill', hue = 'smoker')
